# %% [markdown]
# # Building a conversational chatbot using Rasa

# %% [markdown]
# ## Import statements

# %%
import logging, json, warnings
warnings.filterwarnings('ignore')
logging.basicConfig(level='INFO')

import rasa.nlu
import rasa.core
import spacy

# %% [markdown]
# ## NLU training data

# %%
nlu_md = """
## intent:greet
- hey
- hello there
- hi
- yo
- yo what up
- hello there
- good morning
- good evening
- moin
- hey there
- let's go
- hey dude
- goodmorning
- goodevening
- good afternoon

## intent:goodbye
- cu
- pce
- good by
- cee you later
- good night
- good afternoon
- bye
- goodbye
- have a nice day
- see you around
- bye bye
- later
- see you later

## intent:affirm
- yes
- indeed
- of course
- that sounds good
- correct

## intent:deny
- no
- never
- I don't think so
- don't like that
- no way
- not really
- not what I want

## intent: request_flight
- I want to go on a trip
- I want to book a flight
- I want to book a trip
- Need a ticket 
- Help me find a flight
- Get me out of here
- I want to travel
- I want to fly somewhere

## intent: inform
- from [Toronto] (place:origin)
- I'm coming from [New York] (place:origin)
- I'm going to [Florida] (place:destination)
- to [Tokyo] (place:destination)
- from [aug 10] (date:depart_date)
- leaving [may 4] (date:depart_date)
- to [aug 20] (date:return_date)
- come back [may 18] (date:return_date)
- budget is [$2000] (budget)
- no more than [1000] (budget)
- max [$400] (budget)
- [100 dollars] (budget)
- 100 - [200] (budget)
"""

# %store nlu_md > nlu.md
# Out:
# Writing 'nlu_md' (str) to file 'nlu.md'.

# %% [markdown]
# ## NLU model configuration

# %%
config = """
language: "en"

pipeline:
- name: "nlp_spacy"                   # loads the spacy language model
- name: "tokenizer_spacy"             # splits the sentence into tokens
- name: "ner_crf"                   # uses the pretrained spacy NER model
- name: "intent_featurizer_spacy"     # transform the sentence into a vector representation
- name: "intent_classifier_sklearn"   # uses the vector representation to classify using SVM
- name: "ner_synonyms"                # trains the synonyms
""" 
# %store config > config.yml
# Out:
# Writing 'config' (str) to file 'config.yml'.

# %% [markdown]
# ## Train NLU model

# %%
from rasa.nlu.training_data import load_data
from rasa.nlu.config import RasaNLUModelConfig
from rasa.nlu.model import Trainer
from rasa.nlu import config

# loading the nlu training samples
training_data = load_data("nlu.md")

# trainer to educate our pipeline
trainer = Trainer(config.load("config.yml"))

# train the model!
interpreter = trainer.train(training_data)

# store it for future use
model_directory = trainer.persist("./models/nlu", fixed_model_name="current")
# Out:
# INFO:rasa.nlu.utils.spacy_utils:Trying to load spacy model with name 'en'
# INFO:rasa.nlu.components:Added 'SpacyNLP' to component cache. Key 'SpacyNLP-en'.
# INFO:rasa.nlu.model:Starting to train component SpacyNLP
# INFO:rasa.nlu.model:Finished training component.
# INFO:rasa.nlu.model:Starting to train component SpacyTokenizer
# INFO:rasa.nlu.model:Finished training component.
# INFO:rasa.nlu.model:Starting to train component CRFEntityExtractor
# INFO:rasa.nlu.model:Finished training component.
# INFO:rasa.nlu.model:Starting to train component SpacyFeaturizer
# INFO:rasa.nlu.model:Finished training component.
# INFO:rasa.nlu.model:Starting to train component SklearnIntentClassifier
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:    0.1s finished
# INFO:rasa.nlu.model:Finished training component.
# INFO:rasa.nlu.model:Starting to train component EntitySynonymMapper
# INFO:rasa.nlu.model:Finished training component.
# INFO:rasa.nlu.model:Successfully saved model into '/Users/gthorani/unit_6/travel_chatbot/models/nlu/current'
# Fitting 2 folds for each of 6 candidates, totalling 12 fits

# %% [markdown]
# ## Let's evaluate the NLU model with a sample text

# %%
def pprint(o):   
    print(json.dumps(o, indent=2))
    
pprint(interpreter.parse("my budget is $1000"))
# Out:
# {
#   "intent": {
#     "name": "inform",
#     "confidence": 0.31947327927665653
#   },
#   "entities": [],
#   "intent_ranking": [
#     {
#       "name": "inform",
#       "confidence": 0.31947327927665653
#     },
#     {
#       "name": "goodbye",
#       "confidence": 0.18536832891193372
#     },
#     {
#       "name": "request_flight",
#       "confidence": 0.1787035299373614
#     },
#     {
#       "name": "deny",
#       "confidence": 0.15855202924650416
#     },
#     {
#       "name": "greet",
#       "confidence": 0.08765807022611286
#     },
#     {
#       "name": "affirm",
#       "confidence": 0.07024476240143165
#     }
#   ],
#   "text": "my budget is $1000"
# }

# %% [markdown]
# ## Evaluating NLU model on test data
#
# (Definitely want to use unseen data, but will be using the data we have)

# %%
from rasa.nlu.test import run_evaluation

run_evaluation('nlu.md', model_directory)
# Out:
# INFO:rasa.nlu.components:Added 'SpacyNLP' to component cache. Key 'SpacyNLP-en'.
# INFO:rasa.nlu.test:Running model for predictions:
# 100%|██████████| 60/60 [00:00<00:00, 129.64it/s]
# INFO:rasa.nlu.test:Intent evaluation results:
# INFO:rasa.nlu.test:Intent Evaluation: Only considering those 60 examples that have a defined intent out of 60 examples
# INFO:rasa.nlu.test:F1-Score:  0.8645524691358024
# INFO:rasa.nlu.test:Precision: 0.8397603485838779
# INFO:rasa.nlu.test:Accuracy:  0.9
# INFO:rasa.nlu.test:Classification report:
#                 precision    recall  f1-score   support
#
#         inform       1.00      1.00      1.00        13
#        goodbye       0.76      1.00      0.87        13
#          greet       1.00      0.93      0.96        14
# request_flight       1.00      1.00      1.00         8
#         affirm       0.00      0.00      0.00         5
#           deny       0.78      1.00      0.88         7
#
#       accuracy                           0.90        60
#      macro avg       0.76      0.82      0.78        60
#   weighted avg       0.84      0.90      0.86        60
#
# INFO:rasa.nlu.test:Entity evaluation results:
# INFO:rasa.nlu.test:Evaluation for entity extractor: CRFEntityExtractor
# WARNING:rasa.nlu.test:No labels to evaluate. Skip evaluation.
# {'intent_evaluation': {'predictions': [{'text': 'hey',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.5169613133002935},
#    {'text': 'hello there',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.5065495142929974},
#    {'text': 'hi',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.5125129581708457},
#    {'text': 'yo',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.5069989987149721},
#    {'text': 'yo what up',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.4723252405708644},
#    {'text': 'good morning',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.49399432870478466},
#    {'text': 'good evening',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.48707208843195393},
#    {'text': 'moin',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.5244220259971187},
#    {'text': 'hey there',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.5139070310459841},
#    {'text': "let's go",
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.5242109030687938},
#    {'text': 'hey dude',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.515940011718058},
#    {'text': 'goodmorning',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.6420419572212525},
#    {'text': 'goodevening',
#     'intent': 'greet',
#     'predicted': 'greet',
#     'confidence': 0.6833555576745548},
#    {'text': 'good afternoon',
#     'intent': 'greet',
#     'predicted': 'goodbye',
#     'confidence': 0.3938774872090093},
#    {'text': 'cu',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.41185327310490855},
#    {'text': 'pce',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.4329675052845026},
#    {'text': 'good by',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.4284061097751237},
#    {'text': 'cee you later',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.3814853525621029},
#    {'text': 'good night',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.434962000957979},
#    {'text': 'good afternoon',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.3938774872090093},
#    {'text': 'bye',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.4396634522815559},
#    {'text': 'goodbye',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.4654122935817655},
#    {'text': 'have a nice day',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.41616391265131825},
#    {'text': 'see you around',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.40853067014265765},
#    {'text': 'bye bye',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.4388117495664585},
#    {'text': 'later',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.4328635417449038},
#    {'text': 'see you later',
#     'intent': 'goodbye',
#     'predicted': 'goodbye',
#     'confidence': 0.3840335460159656},
#    {'text': 'yes',
#     'intent': 'affirm',
#     'predicted': 'goodbye',
#     'confidence': 0.42144913017217056},
#    {'text': 'indeed',
#     'intent': 'affirm',
#     'predicted': 'deny',
#     'confidence': 0.3634027012231735},
#    {'text': 'of course',
#     'intent': 'affirm',
#     'predicted': 'goodbye',
#     'confidence': 0.3555235858808649},
#    {'text': 'that sounds good',
#     'intent': 'affirm',
#     'predicted': 'deny',
#     'confidence': 0.4284694214690956},
#    {'text': 'correct',
#     'intent': 'affirm',
#     'predicted': 'goodbye',
#     'confidence': 0.40592249023654126},
#    {'text': 'no',
#     'intent': 'deny',
#     'predicted': 'deny',
#     'confidence': 0.3914162340854169},
#    {'text': 'never',
#     'intent': 'deny',
#     'predicted': 'deny',
#     'confidence': 0.4219770833345888},
#    {'text': "I don't think so",
#     'intent': 'deny',
#     'predicted': 'deny',
#     'confidence': 0.3685484174038962},
#    {'text': "don't like that",
#     'intent': 'deny',
#     'predicted': 'deny',
#     'confidence': 0.37353871706344965},
#    {'text': 'no way',
#     'intent': 'deny',
#     'predicted': 'deny',
#     'confidence': 0.37404224688932813},
#    {'text': 'not really',
#     'intent': 'deny',
#     'predicted': 'deny',
#     'confidence': 0.4715257954505209},
#    {'text': 'not what I want',
#     'intent': 'deny',
#     'predicted': 'deny',
#     'confidence': 0.3629527819194651},
#    {'text': 'I want to go on a trip',
#     'intent': 'request_flight',
#     'predicted': 'request_flight',
#     'confidence': 0.49834370383093274},
#    {'text': 'I want to book a flight',
#     'intent': 'request_flight',
#     'predicted': 'request_flight',
#     'confidence': 0.5258461322568567},
#    {'text': 'I want to book a trip',
#     'intent': 'request_flight',
#     'predicted': 'request_flight',
#     'confidence': 0.5792960166327634},
#    {'text': 'Need a ticket',
#     'intent': 'request_flight',
#     'predicted': 'request_flight',
#     'confidence': 0.5495807404245079},
#    {'text': 'Help me find a flight',
#     'intent': 'request_flight',
#     'predicted': 'request_flight',
#     'confidence': 0.5412741298413016},
#    {'text': 'Get me out of here',
#     'intent': 'request_flight',
#     'predicted': 'request_flight',
#     'confidence': 0.5029689322861117},
#    {'text': 'I want to travel',
#     'intent': 'request_flight',
#     'predicted': 'request_flight',
#     'confidence': 0.5618184359013417},
#    {'text': 'I want to fly somewhere',
#     'intent': 'request_flight',
#     'predicted': 'request_flight',
#     'confidence': 0.5305196318505019},
#    {'text': 'from [Toronto] (place:origin)',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.6886718230726396},
#    {'text': "I'm coming from [New York] (place:origin)",
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.6465384102581843},
#    {'text': "I'm going to [Florida] (place:destination)",
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.6891242417201187},
#    {'text': 'to [Tokyo] (place:destination)',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.7261829471396892},
#    {'text': 'from [aug 10] (date:depart_date)',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.6872076139624772},
#    {'text': 'leaving [may 4] (date:depart_date)',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.7297818640940982},
#    {'text': 'to [aug 20] (date:return_date)',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.6866152572280672},
#    {'text': 'come back [may 18] (date:return_date)',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.6440884707981359},
#    {'text': 'budget is [$2000] (budget)',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.7549119087277616},
#    {'text': 'no more than [1000] (budget)',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.6602351766834115},
#    {'text': 'max [$400] (budget)',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.8136211586653611},
#    {'text': '[100 dollars] (budget)',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.8211604673747982},
#    {'text': '100 - [200] (budget)',
#     'intent': 'inform',
#     'predicted': 'inform',
#     'confidence': 0.8708005583656971}],
#   'report': '                precision    recall  f1-score   support\n\n        inform       1.00      1.00      1.00        13\n       goodbye       0.76      1.00      0.87        13\n         greet       1.00      0.93      0.96        14\nrequest_flight       1.00      1.00      1.00         8\n        affirm       0.00      0.00      0.00         5\n          deny       0.78      1.00      0.88         7\n\n      accuracy                           0.90        60\n     macro avg       0.76      0.82      0.78        60\n  weighted avg       0.84      0.90      0.86        60\n',
#   'precision': 0.8397603485838779,
#   'f1_score': 0.8645524691358024,
#   'accuracy': 0.9},
#  'entity_evaluation': {'CRFEntityExtractor': {'report': {},
#    'precision': 0.0,
#    'f1_score': 0.0,
#    'accuracy': 0.0}},
#  'response_selection_evaluation': None}

# %% [markdown]
# ## Using Rasa core to teach the bot to respond

# %%
stories_md = """
## flight path
* request_flight
    - utter_ask_to_where
* inform{'place':'destination'}
    - utter_ask_from_where 
* inform{'place':'origin'}
    - utter_ask_duration
* inform{'date':'depart_date','date':'return_date'}
    - utter_budget
* inform{'budget':'$1000'}
    - utter_flight_offer
    - utter_ok
* affirm
    - goodbye

## flight path 1
* request_flight
* inform{'place':'origin'}
* inform{'place':'destination'}
* inform{'date':'depart_date','date':'return_date'}
* inform{'budget':'$1000'}
    - utter_flight_offer
    - utter_ok
* affirm
    - goodbye



## say goodbye
* goodbye
  - utter_goodbye

## fallback
- utter_unclear

"""

# %store stories_md > stories.md
